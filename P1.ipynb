# %%
print(2+2)
# Out:
# 4

# %%
print('sanzid')
# Out:
# sanzid

# %%
var = 100

# %%
import sys
sys.getsizeof(var)
# Out:
# 28

# %%
x=100

# %%
x
# Out:
# 100

# %%
id(x)
# Out:
# 4301630464

# %%
id(var)
# Out:
# 4301630464

# %%
name ='abul'

# %%
name
# Out:
# 'abul'
